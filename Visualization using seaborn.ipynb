# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
tip = sns.load_dataset('tips')

# %%
tip.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# # 1) Exploring different types of plots in seaborn

# %%
sns.distplot(tip['total_bill'])

# %%
sns.distplot(data['tip'])
sns.distplot(data['size'])

# %%
sns.distplot(data['tip'],kde=False)
sns.distplot(data['size'],kde=False)

# %%
sns.kdeplot(tip['tip'],data2=tip['size'])

# %%
sns.kdeplot(tip['tip'],data2=tip['size'],kind='kde')
# Out:
# D:\Installed\Anaconda3\lib\site-packages\seaborn\distributions.py:437: UserWarning: The following kwargs were not used by contour: 'kind'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %%
sns.jointplot(x='total_bill',y='tip',data=tip)

# %%
sns.jointplot(x='total_bill',y='tip',data=tip,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=tip,kind='hex')

# %%
sns.pairplot(tip,hue='sex')

# %%
sns.pairplot(tip,hue='sex',diag_kind='hist')

# %%
# Out:
# D:\Installed\Anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.rugplot(tip['total_bill'])

# %%
sns.barplot(x='sex',y='total_bill',data=tip)

# %%
g = sns.countplot(x='size',data=tip,hue='smoker', color='steelblue')
g.set_xticks([0,1,2,3,4,5,6])
g.set_xticklabels(['zero','one','two','three','four','five','six'])
# Out:
# [Text(0, 0, 'zero'),
#  Text(0, 0, 'one'),
#  Text(0, 0, 'two'),
#  Text(0, 0, 'three'),
#  Text(0, 0, 'four'),
#  Text(0, 0, 'five'),
#  Text(0, 0, 'six')]

# %%
sns.countplot(x='sex',data=tip)

# %%
sns.boxplot(x='sex',y='total_bill',data=tip)

# %%
sns.violinplot(x='sex',y='total_bill',data=tip)

# %%
sns.violinplot('size','tip',data=tip,palette=['lightblue','lightpink'],hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill', data=tip)

# %%
sns.stripplot(x='day',y='total_bill', data=tip, hue='sex')

# %%
sns.swarmplot(x='sex',y='total_bill',data=tip)

# %%
sns.violinplot(x='sex', data=tip, y='total_bill')
sns.swarmplot(x='sex', data=tip, y='total_bill',color='black')

# %%
pt = tip.pivot_table(values='tip', index='time', columns=['size','smoker'])

# %%
pt
# Out:
# size       1               2                3               4              5  \
# smoker   Yes    No       Yes        No    Yes        No   Yes        No  Yes
# time
# Lunch   1.92  1.83  2.613333  2.322353  3.615  2.180000  4.50  4.030000  NaN
# Dinner  1.00  1.00  2.745625  2.590179  4.191  3.185217  3.88  4.217391  2.5
#
# size            6
# smoker    No   No
# time
# Lunch   5.00  5.3
# Dinner  5.07  5.0

# %%
sns.heatmap(pt,linecolor='white', linewidths=1)

# %%
sns.PairGrid(tip,hue='sex').map(plt.scatter)

# %%
g = sns.PairGrid(tip, hue='sex',vars=['total_bill', 'tip', 'smoker']).map(plt.scatter, alpha=0.5)
g.add_legend()

# %%
sns.FacetGrid(data=tip, row='sex',col='day').map(plt.hist, 'tip')

# %%
import numpy as np
