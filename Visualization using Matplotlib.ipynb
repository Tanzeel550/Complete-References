# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# # 1) Basic figure

# %%
x= np.linspace(0,10,100)

# %%
fig = plt.figure()
plt.plot(x,np.sin(x),'--')
plt.plot(x,np.cos(x),'-')

# %% [markdown]
# ### Saving Fig

# %%
fig.savefig("myfig.jpg")

# %%
from IPython.display import Image

# %%
Image("myfig.jpg")

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# # 2) Matlab style fig

# %%
plt.figure()

plt.subplot(3,1,1)#(no of rows, no of column, current fig no.)
plt.plot(x,np.sin(x))

plt.subplot(3,1,2)
plt.plot(x,np.cos(x))

plt.subplot(3,1,3)
plt.plot(x,np.tan(x))

# %% [markdown]
# # 3) Object Oriented Approach

# %%
# First create a grid of plots. ax will be an array of three Axes objects
fig, ax = plt.subplots(3)# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))
ax[2].plot(x, np.tan(x))

# %% [markdown]
# # 4) Simple Line Plot

# %%
fig = plt.figure()
#Create a new figure. or it acts as figure on which plot (subplots) is created
# It contains  all  the  objects  representing  axes,  graphics,  text,  and labels
ax = plt.axes()
#Create an axes, without this plt.fiure cannot do anything
# axes contain the plot elementes which make up a plot like labels, titles, ticks

# %%
plt.plot(x,np.sin(x))

# %%
# if we want to create multiple line plots in a single fig, we can use many plt.plot at the same time
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
# plt.plot(x,np.tan(x))

# %% [markdown]
# ### plot color, label

# %%
plt.plot(x, np.sin(x), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')
# For short, you can use the following codes:plt.plot(x, x + 4, linestyle='-')  
# solidplt.plot(x, x + 5, linestyle='--') 
# dashedplt.plot(x, x + 6, linestyle='-.') 
# dashdotplt.plot(x, x + 7, linestyle=':');  # dotted

# %%
# we can use color and style at the same time
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# ### Adjusting plot limits

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.1, 1.1)
# Out:
# (-1.1, 1.1)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# plt.axis([xmin, xmax, ymin,ymax])
# Out:
# [-1, 11, -1.5, 1.5]

# %%
plt.plot(x, np.sin(x))
plt.axis('auto')
# plt.axis has many more optiones like
# equal, on, off, auto, normal, square, tight
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x,np.sin(x))
plt.xlabel("X")
plt.ylabel("sin(X)")
# Out:
# Text(0, 0.5, 'sin(X)')

# %%
plt.plot(x,np.sin(x))
plt.xlabel("X")
plt.ylabel("sin(X)")
plt.title("My fig")
# Out:
# Text(0.5, 1.0, 'My fig')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.legend();

# %% [markdown]
# ### objected oriented approach

# %%
# ax = plt.axes()ax.plot(x, np.sin(x))ax.set(xlim=(0, 10), ylim=(-2, 2),xlabel='x', ylabel='sin(x)',title='A Simple Plot')

# %%
ax = plt.axes()
ax.plot(x,np.sin(x))
ax.set_xlabel("X")
ax.set_ylabel("sin(X)")
ax.set_title("My fig")
# Out:
# Text(0.5, 1.0, 'My fig')

# %%
ax = plt.axes()
ax.plot(x,np.sin(x))
ax.plot(x,np.cos(x))
ax.set_xlabel("X")
ax.set_ylabel("sin(X)")
ax.set_title("My fig")
plt.legend(['x','sin(X)'])

# %%
ax = plt.axes()
ax.plot(x,np.sin(x))
ax.plot(x,np.cos(x))
ax.set()
# Out:
# []

# %% [markdown]
# # 5) Scatter plots

# %% [markdown]
# ### Scatter plot with plt.plot

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

# %%
plt.plot(x,np.sin(x),'o', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,label="marker='{0}'".format(marker))
    
    plt.legend(numpoints=1)
    plt.xlim(0, 1.8)

# %%
plt.plot(x, y, '-p', color='gray',markersize=15, linewidth=4,markerfacecolor='white',markeredgecolor='gray',markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ### using plt.scatter

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,c= 'black')
# c is the color of markers

# %%
plt.scatter(x,y, marker='*',s=100,cmap='virdis')
# if cmap is used then c must be omitted
# s is the size of marker
# different markers can be used like in above examples

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.randn(100)
size = 1000*np.random.randn(100)
plt.scatter(x,y, c = colors, s=size, cmap='rainbow',alpha=0.3,edgecolors='black')
# alpha is used to set the transperency of each marker
plt.colorbar()#color bar shows the color bar
# Out:
# D:\Installed\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# # 6) Histograms, binnings & Density

# %%
plt.hist(x)
# Out:
# (array([ 2.,  4.,  5., 14., 26., 22., 16.,  8.,  2.,  1.]),
#  array([-2.76466099, -2.2095825 , -1.654504  , -1.09942551, -0.54434701,
#          0.01073149,  0.56580998,  1.12088848,  1.67596698,  2.23104547,
#          2.78612397]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, bins=50, alpha=0.5,histtype='bar', color='red',edgecolor='black')
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  0.,  3.,  0.,  2.,  1.,
#          0.,  2.,  4.,  3.,  1.,  2.,  4., 10.,  4.,  2.,  6.,  4.,  2.,
#          5.,  5.,  5.,  5.,  5.,  3.,  2.,  4.,  2.,  2.,  3.,  1.,  1.,
#          1.,  0.,  1.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([-2.76466099, -2.65364529, -2.5426296 , -2.4316139 , -2.3205982 ,
#         -2.2095825 , -2.0985668 , -1.9875511 , -1.8765354 , -1.7655197 ,
#         -1.654504  , -1.5434883 , -1.4324726 , -1.3214569 , -1.2104412 ,
#         -1.09942551, -0.98840981, -0.87739411, -0.76637841, -0.65536271,
#         -0.54434701, -0.43333131, -0.32231561, -0.21129991, -0.10028421,
#          0.01073149,  0.12174719,  0.23276289,  0.34377859,  0.45479428,
#          0.56580998,  0.67682568,  0.78784138,  0.89885708,  1.00987278,
#          1.12088848,  1.23190418,  1.34291988,  1.45393558,  1.56495128,
#          1.67596698,  1.78698268,  1.89799837,  2.00901407,  2.12002977,
# ...

# %%
plt.hist(x, bins=30, alpha=0.5,histtype='bar', color='red',edgecolor='black',align='right',orientation="horizontal")
# align will allign the bins in the center, not commonly used
# orietation is used to set the orientation of the plot
# Out:
# (array([ 2.,  0.,  0.,  1.,  0.,  3.,  1.,  2.,  2.,  6.,  4.,  4., 12.,
#          6.,  8.,  5., 10.,  7.,  7.,  5.,  4.,  4.,  2.,  2.,  1.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([-2.76466099, -2.57963483, -2.39460866, -2.2095825 , -2.02455633,
#         -1.83953017, -1.654504  , -1.46947784, -1.28445167, -1.09942551,
#         -0.91439934, -0.72937317, -0.54434701, -0.35932084, -0.17429468,
#          0.01073149,  0.19575765,  0.38078382,  0.56580998,  0.75083615,
#          0.93586231,  1.12088848,  1.30591465,  1.49094081,  1.67596698,
#          1.86099314,  2.04601931,  2.23104547,  2.41607164,  2.6010978 ,
#          2.78612397]),
#  <a list of 30 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# D:\Installed\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """
# D:\Installed\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# D:\Installed\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   import sys
# (array([0.00642429, 0.00321215, 0.        , 0.00321215, 0.01284858,
#         0.01927287, 0.02248502, 0.01606073, 0.01927287, 0.03854574,
#         0.06103076, 0.06103076, 0.0706672 , 0.10278865, 0.17345584,
#         0.12206152, 0.16060726, 0.16381941, 0.22163802, 0.2055773 ,
#         0.2055773 , 0.21521373, 0.18630443, 0.19594086, 0.12527367,
# ...

# %% [markdown]
# ### 2d historgrams

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
plt.hist2d(x, y, bins=30, cmap='Blues',cmin =10, cmax =20)
# cmin will not show bins below the cmin
# cmax will not show bins above the cmax
cb = plt.colorbar()
cb.set_label('counts in bin')
# Out:
# D:\Installed\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7080: RuntimeWarning: invalid value encountered in greater
#   h[h > cmax] = None

# %% [markdown]
# # 7) Customizing plot legends

# %%
x = np.linspace(0,10,1000)
sinx = np.sin(x)
cosx = np.cos(x)
tanx = np.tan(x)

# %%
plt.plot(x,sinx,label='sin(x)')
plt.plot(x,cosx,label='cos(x)')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x),label='Sine')
ax.plot(x, np.cos(x),label='Cosine')
leg = ax.legend()

# %%
ax.legend(loc='best', frameon=False)
fig
# loc is used to fix the location of legend, in our case it is best
# it can be ['upper left', 'upper right', 'lower left', 'lower right', 'upper center', 'lower center', 'center left', 'center right']
# frameon : the name shows everything. if frameon is False, then frame of legend will not be shown

# %%
ax.legend(loc='lower left', ncol=2)
fig
# ncol : We  can  use  the  ncol  command  to  specify  the  number  of  columns  in  the  legend

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig
#fancybox is used to make rounded legend box
# framealpha is used to set the transperency of the box
# shadow is used to show the shadow of the box
# borderpad is used to add padding to the text inside the box

# %%
ax.legend(['sin','cos'])
fig

# %% [markdown]
# # 8) Multiple subplots

# %% [markdown]
# ### fig.axes

# %%
ax1=plt.axes()
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])
ax1.plot(x,sinx)
ax2.plot(x,cosx)
# [bottom,  left,  width,height]

# %% [markdown]
# Object Oriented Approach

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
# ax1 = fig.add_axes([1,1,1,1])
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])

ax1.plot(sinx)
ax2.plot(cosx)

# %% [markdown]
# ### plt.subplot

# %%
plt.figure()

plt.subplot(3,1,1)#(no of rows, no of column, current fig no.)
plt.plot(x,np.sin(x))

plt.subplot(3,1,2)
plt.plot(x,np.cos(x))

plt.subplot(3,1,3)
plt.plot(x,np.tan(x))

# %% [markdown]
# Object Oriented Approach

# %%
# First create a grid of plots. ax will be an array of three Axes objects
fig, ax = plt.subplots(3)# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))
ax[2].plot(x, np.tan(x))
# the number of subplots to be created depends upon the number given plt.subplots() argument

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)#the  number  of  rows,  the  number  of  col‐umns,  and  the  index  of  the  plot  to  be  created
    plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')

# %%
for i in range(1, 10):
    plt.subplot(3, 3, i)#the  number  of  rows,  the  number  of  col‐umns,  and  the  index  of  the  plot  to  be  created
    plt.plot(x,sinx)
#     plt.text(0.5, 0.5, str((3, 3, i)),fontsize=18, ha='center')

# %% [markdown]
# ### plt.subplots

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
arr = [sinx, cosx, tanx,sinx,cosx,tanx]
for i in range(2):
    for j in range(3):
        ax[i,j].plot(x,arr[i+j])
#         ax[i, j].text(0.5, 0.5, str((i, j)),fontsize=18, ha='center')
fig

# %% [markdown]
# # 9) Customizing ticks

# %%
y = np.linspace(0,10,10)
siny = np.sin(y)
cosy = np.cos(y)
tany = np.tan(y)

# %%
fig = plt.figure()
ax = plt.axes()
plt.plot(y,siny)

ax.set_xticks(np.arange(0,11))
ax.set_yticks(np.linspace(-1,1,10))

# %%
num=np.arange(0, 3.14*2, 0.05)
fig=plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
sinnum=np.sin(num)
ax.plot(num, sinnum)

ax.set_xlabel('angle')
ax.set_title('sine')
ax.set_xticklabels(['zero','two','four','six'])
# Out:
# [Text(0, 0, 'zero'), Text(0, 0, 'two'), Text(0, 0, 'four'), Text(0, 0, 'six')]

# %%
fig = plt.figure()
ax = plt.axes()

plt.plot(y,siny)
ax.set_xticks(np.arange(0,10))
ax.set_xticklabels(['one','two','three','four','five','six','seven','eight','nine','ten','elevn'])
#note that xticklabels are correspondence to xticks and the same will happen for yticks

ax.set_yticks(np.linspace(-1,1,5))
ax.set_yticklabels(['-one', '-zero.five','zero','zero.five','one'])
# Out:
# [Text(0, 0, '-one'),
#  Text(0, 0, '-zero.five'),
#  Text(0, 0, 'zero'),
#  Text(0, 0, 'zero.five'),
#  Text(0, 0, 'one')]

# %%
ax=plt.axes(xscale='log',yscale='log')
# xscale: {"linear", "log", "symlog", "logit"}
# yscale: {"linear", "log", "symlog", "logit"}

# %%
print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())

print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())

# %% [markdown]
# ### Hiding ticks and lables

# %% [markdown]
# We’ve  removed  the  labels  (but  kept  the  ticks/gridlines)  from  the  x  axis,and removed the ticks (and thus the labels as well) from the y axis

# %%
ax = plt.axes()
plt.plot(y,siny)

ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_locator(plt.NullLocator())

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %% [markdown]
# ### limiting the number of ticks

# %% [markdown]
# Matplotlib will use its inner logic to set the particular location for a tick

# %%
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(1))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))
fig

# %% [markdown]
# # 10) Mapping with Basemap

# %%
import os
os.environ["PROJ_LIB"] = "D:\\Installed\\Anaconda3\\Library\\share";
import mpl_toolkits.basemap as bmp

# %%
plt.figure(figsize=(8, 8))
m = bmp.Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
dir(mpl)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'axes_grid1']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-a9c6bb867a48> in <module>
# ----> 1 mpl.basemap
#
# AttributeError: module 'mpl_toolkits' has no attribute 'basemap'
